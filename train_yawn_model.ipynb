# %%
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/opt/anaconda3/envs/yawning_model/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel/utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/h2/wm9znrpn1t91bqtr9g3njc7h0000gn/T/ipykernel_76488/3024022000.py", line 1, in <module>
#     import tensorflow as tf
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/tensorflow/__init__.py", line 468, in <module>
#     importlib.import_module("keras.src.optimizers")
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/keras/__init__.py", line 7, in <module>
#     from keras import _tf_keras as _tf_keras
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/keras/_tf_keras/__init__.py", line 1, in <module>
#     from keras._tf_keras import keras
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/keras/_tf_keras/keras/__init__.py", line 7, in <module>
#     from keras import activations as activations
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/keras/activations/__init__.py", line 7, in <module>
#     from keras.src.activations import deserialize as deserialize
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/keras/src/__init__.py", line 13, in <module>
#     from keras.src import visualization
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/keras/src/visualization/__init__.py", line 1, in <module>
#     from keras.src.visualization import draw_bounding_boxes
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/keras/src/visualization/draw_bounding_boxes.py", line 11, in <module>
#     import cv2
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/cv2/__init__.py", line 181, in <module>
#     bootstrap()
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/cv2/__init__.py", line 153, in bootstrap
#     native_module = importlib.import_module("cv2")
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import tensorflow as tf
# ----> 2 import matplotlib.pyplot as plt
#       4 from tensorflow.keras.preprocessing.image import ImageDataGenerator
#       5 from tensorflow.keras.applications import MobileNetV2
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import tensorflow as tf
import numpy as np
import cv2

print("TensorFlow:", tf.__version__)
print("NumPy:", np.__version__)
print("OpenCV:", cv2.__version__)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/opt/anaconda3/envs/yawning_model/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel/utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/h2/wm9znrpn1t91bqtr9g3njc7h0000gn/T/ipykernel_70295/1306086789.py", line 1, in <module>
#     import tensorflow as tf
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/tensorflow/__init__.py", line 468, in <module>
#     importlib.import_module("keras.src.optimizers")
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/keras/__init__.py", line 7, in <module>
#     from keras import _tf_keras as _tf_keras
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/keras/_tf_keras/__init__.py", line 1, in <module>
#     from keras._tf_keras import keras
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/keras/_tf_keras/keras/__init__.py", line 7, in <module>
#     from keras import activations as activations
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/keras/activations/__init__.py", line 7, in <module>
#     from keras.src.activations import deserialize as deserialize
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/keras/src/__init__.py", line 13, in <module>
#     from keras.src import visualization
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/keras/src/visualization/__init__.py", line 1, in <module>
#     from keras.src.visualization import draw_bounding_boxes
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/keras/src/visualization/draw_bounding_boxes.py", line 11, in <module>
#     import cv2
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/cv2/__init__.py", line 181, in <module>
#     bootstrap()
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/cv2/__init__.py", line 153, in bootstrap
#     native_module = importlib.import_module("cv2")
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/opt/anaconda3/envs/yawning_model/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel/utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/opt/anaconda3/envs/yawning_model/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/h2/wm9znrpn1t91bqtr9g3njc7h0000gn/T/ipykernel_70295/1306086789.py", line 3, in <module>
#     import cv2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import tensorflow as tf
#       2 import numpy as np
# ----> 3 import cv2
#       5 print("TensorFlow:", tf.__version__)
#       6 print("NumPy:", np.__version__)
#
# ImportError: numpy.core.multiarray failed to import
